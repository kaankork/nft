# %%
import pandas as pd

# %%
df = pd.read_csv('../data/mutant-ape-collection_PREPROCESSED.csv', index_col=0)

# %% [markdown]
# ## Initial Analysis

# %%
include=["int64", "object"]
df.describe(include=include)
# Out:
#                   id      token_id  \
# count   1.184300e+04  11843.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean    4.605787e+07   6133.845394
# std     1.948876e+07   3781.787504
# min     4.218842e+07      0.000000
# 25%     4.219661e+07   2960.500000
# 50%     4.220168e+07   5921.000000
# 75%     4.220609e+07   8881.500000
# max     1.906658e+08  14648.000000
#
#                             asset_contract_address  \
# count                                        11843
# unique                                           1
# top     0x60e4d786628fea6478f785a6d7e704777c86a7c6
# freq                                         11843
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#                                                 permalink  \
# count                                               11843
# unique                                              11843
# top     https://opensea.io/assets/0x60e4d786628fea6478...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    traits  \
# count                                               11843
# unique                                              11843
# top     [{'trait_type': 'Mouth', 'value': 'M1 Bored Un...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                        image_original_url  \
# count                                               11843
# unique                                              11843
# top     https://ipfs.io/ipfs/QmURua8bNrAwX76Tp6G9t6Los...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                       created_date                current_price  \
# count                        11843                        11843
# unique                           1                          530
# top     2021-08-29T00:41:59.548458  Not on sale. Taking offers.
# freq                         11843                         9800
# mean                           NaN                          NaN
# std                            NaN                          NaN
# min                            NaN                          NaN
# 25%                            NaN                          NaN
# 50%                            NaN                          NaN
# 75%                            NaN                          NaN
# max                            NaN                          NaN
#
#        last_sale_total_price last_sale_event_timestamp  ... value_hat  \
# count                  11843                     11843  ...     11843
# unique                  1498                      7912  ...        73
# top           Not available.            Not available.  ...         -
# freq                    3362                      3362  ...      2645
# mean                     NaN                       NaN  ...       NaN
# std                      NaN                       NaN  ...       NaN
# min                      NaN                       NaN  ...       NaN
# 25%                      NaN                       NaN  ...       NaN
# 50%                      NaN                       NaN  ...       NaN
# 75%                      NaN                       NaN  ...       NaN
# max                      NaN                       NaN  ...       NaN
#
#        display_type_hat max_value_hat trait_count_hat order_hat value_mouth  \
# count              2645          2645           11843      2645       11843
# unique                1             1              65         1          67
# top                   -             -               -         -    M1 Bored
# freq               2645          2645            2645      2645        2039
# mean                NaN           NaN             NaN       NaN         NaN
# std                 NaN           NaN             NaN       NaN         NaN
# min                 NaN           NaN             NaN       NaN         NaN
# 25%                 NaN           NaN             NaN       NaN         NaN
# 50%                 NaN           NaN             NaN       NaN         NaN
# 75%                 NaN           NaN             NaN       NaN         NaN
# max                 NaN           NaN             NaN       NaN         NaN
#
#        display_type_mouth max_value_mouth trait_count_mouth order_mouth
# count                   5               5             11843           5
# unique                  1               1                60           1
# top                     -               -              3032           -
# freq                    5               5              2039           5
# mean                  NaN             NaN               NaN         NaN
# std                   NaN             NaN               NaN         NaN
# min                   NaN             NaN               NaN         NaN
# 25%                   NaN             NaN               NaN         NaN
# 50%                   NaN             NaN               NaN         NaN
# 75%                   NaN             NaN               NaN         NaN
# max                   NaN             NaN               NaN         NaN
#
# [11 rows x 45 columns]

# %%
df['current_price'].value_counts()[0:10]
# Out:
# Not on sale. Taking offers.    9800
# 25.0                            118
# 20.0                             96
# 30.0                             94
# 50.0                             58
# 35.0                             55
# 40.0                             45
# 100.0                            39
# 21.0                             31
# 22.0                             30
# Name: current_price, dtype: int64

# %% [markdown]
# ### Findings
# - All assets are minted under the same contract address
# - All assets have unique traits (obviously)
# - All assets were created on the same data 29.08.2021
# - 9800 assets don't have a sales price (as of data collection date - 08.01.2022)

# %%
df.iloc[4]
# Out:
# id                                                                    42189032
# token_id                                                                     4
# asset_contract_address              0x60e4d786628fea6478f785a6d7e704777c86a7c6
# permalink                    https://opensea.io/assets/0x60e4d786628fea6478...
# traits                       [{'trait_type': 'Background', 'value': 'M1 Yel...
# image_original_url           https://ipfs.io/ipfs/QmWRGQUs6yRUinC8d3woj6dgZ...
# created_date                                        2021-08-29T00:41:59.548458
# current_price                                      Not on sale. Taking offers.
# last_sale_total_price                                           Not available.
# last_sale_event_timestamp                                       Not available.
# value_background                                                     M1 Yellow
# display_type_background                                                    NaN
# max_value_background                                                       NaN
# trait_count_background                                                    1775
# order_background                                                           NaN
# value_clothes                                                    M1 Blue Dress
# display_type_clothes                                                       NaN
# max_value_clothes                                                          NaN
# trait_count_clothes                                                        125
# order_clothes                                                              NaN
# value_earring                                                   M1 Silver Stud
# display_type_earring                                                       NaN
# max_value_earring                                                          NaN
# trait_count_earring                                                       1082
# order_earring                                                              NaN
# value_eyes                                                            M1 Bored
# display_type_eyes                                                          NaN
# max_value_eyes                                                             NaN
# trait_count_eyes                                                          2302
# order_eyes                                                                 NaN
# value_fur                                                         M1 Death Bot
# display_type_fur                                                           NaN
# max_value_fur                                                              NaN
# trait_count_fur                                                            269
# order_fur                                                                  NaN
# value_hat                                                           M1 S&m Hat
# display_type_hat                                                           NaN
# max_value_hat                                                              NaN
# trait_count_hat                                                            307
# order_hat                                                                  NaN
# value_mouth                                                          M1 Jovial
# display_type_mouth                                                         NaN
# max_value_mouth                                                            NaN
# trait_count_mouth                                                          386
# order_mouth                                                                NaN
# Name: 4, dtype: object

# %%
df.iloc[4]['current_price']
# Out:
# 'Not on sale. Taking offers.'
